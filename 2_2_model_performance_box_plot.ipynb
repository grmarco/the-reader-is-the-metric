# %%
from plots import plot_f1

# %%
base_path = "model_results"

# %%
plot_f1(base_path, 'rf')
# Out:
# /data/gmarco/canon_to_github/plots.py:347: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   ax = sns.boxplot(data=f1_test_per_user, palette=palette)

# %%
plot_f1(base_path, 'lr')
# Out:
# /data/gmarco/canon_to_github/plots.py:347: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   ax = sns.boxplot(data=f1_test_per_user, palette=palette)
# Baseline not found for dataset 'hanna'
