# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_content(url):
    try:
        print(f"Scraping content from: {url}")
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extracting only paragraphs within the specified class
        content_div = soup.find('div', class_='body__inner-container')
        if content_div:
            paragraphs = content_div.find_all('p')
            text = ' '.join([p.get_text() for p in paragraphs])
            print(f"Scraping successful for: {url}")
            return text
        else:
            print(f"No content found in specified class for {url}")
            return None
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

def complete_dataset(dataset):
    completed_dataset = []
    for item in dataset:
        print(f"Processing story: {item['story_name']}")
        if item['content'].startswith('http'):
            scraped_text = scrape_content(item['content'])
            if scraped_text:
                item['content'] = scraped_text
        completed_dataset.append(item)
        print(f"Finished processing: {item['story_name']}")
    return completed_dataset

# %%
print("Loading dataset from file...")
with open('input/ttcw_short_stories.json', 'r') as f:
    dataset = json.load(f)

print("Starting the scraping process...")
completed_dataset = complete_dataset(dataset)
with open('completed_dataset.json', 'w') as f:
    json.dump(completed_dataset, f, indent=4, ensure_ascii=False)
print("Dataset completed and saved to 'completed_dataset.json'")
# Out:
# Loading dataset from file...
# Starting the scraping process...
# Processing story: Maintenance, Hvidovre
# Scraping content from: https://www.newyorker.com/magazine/2023/05/15/maintenance-hvidovre-fiction-olga-ravn
# Scraping successful for: https://www.newyorker.com/magazine/2023/05/15/maintenance-hvidovre-fiction-olga-ravn
# Finished processing: Maintenance, Hvidovre
# Processing story: Maintenance, Hvidovre
# Finished processing: Maintenance, Hvidovre
# Processing story: Maintenance, Hvidovre
# Finished processing: Maintenance, Hvidovre
# Processing story: Maintenance, Hvidovre
# Finished processing: Maintenance, Hvidovre
# Processing story: Listening For the Click
# Scraping content from: https://www.newyorker.com/books/flash-fiction/listening-for-the-click
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/listening-for-the-click
# Finished processing: Listening For the Click
# Processing story: Listening For the Click
# Finished processing: Listening For the Click
# Processing story: Listening For the Click
# Finished processing: Listening For the Click
# Processing story: Listening For the Click
# Finished processing: Listening For the Click
# Processing story: The Facade Renovation That's Going Well
# Scraping content from: https://www.newyorker.com/books/flash-fiction/the-facade-renovation-thats-going-well
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/the-facade-renovation-thats-going-well
# Finished processing: The Facade Renovation That's Going Well
# Processing story: The Facade Renovation That's Going Well
# Finished processing: The Facade Renovation That's Going Well
# Processing story: The Facade Renovation That's Going Well
# Finished processing: The Facade Renovation That's Going Well
# Processing story: The Facade Renovation That's Going Well
# Finished processing: The Facade Renovation That's Going Well
# Processing story: The Last Dance with my Dad
# Scraping content from: https://www.newyorker.com/culture/personal-history/the-last-dance-with-my-dad
# Scraping successful for: https://www.newyorker.com/culture/personal-history/the-last-dance-with-my-dad
# Finished processing: The Last Dance with my Dad
# Processing story: The Last Dance with my Dad
# Finished processing: The Last Dance with my Dad
# Processing story: The Last Dance with my Dad
# Finished processing: The Last Dance with my Dad
# Processing story: The Last Dance with my Dad
# Finished processing: The Last Dance with my Dad
# Processing story: Beyond Nature
# Scraping content from: https://www.newyorker.com/books/flash-fiction/beyond-nature
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/beyond-nature
# Finished processing: Beyond Nature
# Processing story: Beyond Nature
# Finished processing: Beyond Nature
# Processing story: Beyond Nature
# Finished processing: Beyond Nature
# Processing story: Beyond Nature
# Finished processing: Beyond Nature
# Processing story: Trash
# Scraping content from: https://www.newyorker.com/magazine/2022/06/13/trash
# Scraping successful for: https://www.newyorker.com/magazine/2022/06/13/trash
# Finished processing: Trash
# Processing story: Trash
# Finished processing: Trash
# Processing story: Trash
# Finished processing: Trash
# Processing story: Trash
# Finished processing: Trash
# Processing story: Barbara,Detroit,1996
# Scraping content from: https://www.newyorker.com/books/flash-fiction/barbara-detroit-1966
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/barbara-detroit-1966
# Finished processing: Barbara,Detroit,1996
# Processing story: Barbara,Detroit,1996
# Finished processing: Barbara,Detroit,1996
# Processing story: Barbara,Detroit,1996
# Finished processing: Barbara,Detroit,1996
# Processing story: Barbara,Detroit,1996
# Finished processing: Barbara,Detroit,1996
# Processing story: Returns
# Scraping content from: https://www.newyorker.com/magazine/2022/11/14/returns
# Scraping successful for: https://www.newyorker.com/magazine/2022/11/14/returns
# Finished processing: Returns
# Processing story: Returns
# Finished processing: Returns
# Processing story: Returns
# Finished processing: Returns
# Processing story: Returns
# Finished processing: Returns
# Processing story: A Triangle
# Scraping content from: https://www.newyorker.com/books/flash-fiction/a-triangle
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/a-triangle
# Finished processing: A Triangle
# Processing story: A Triangle
# Finished processing: A Triangle
# Processing story: A Triangle
# Finished processing: A Triangle
# Processing story: A Triangle
# Finished processing: A Triangle
# Processing story: Certain European Movies
# Scraping content from: https://www.newyorker.com/books/flash-fiction/certain-european-movies
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/certain-european-movies
# Finished processing: Certain European Movies
# Processing story: Certain European Movies
# Finished processing: Certain European Movies
# Processing story: Certain European Movies
# Finished processing: Certain European Movies
# Processing story: Certain European Movies
# Finished processing: Certain European Movies
# Processing story: Keys
# Scraping content from: https://www.newyorker.com/books/flash-fiction/keys
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/keys
# Finished processing: Keys
# Processing story: Keys
# Finished processing: Keys
# Processing story: Keys
# Finished processing: Keys
# Processing story: Keys
# Finished processing: Keys
# Processing story: The Kingdom That Failed
# Scraping content from: https://www.newyorker.com/books/flash-fiction/the-kingdom-that-failed
# Scraping successful for: https://www.newyorker.com/books/flash-fiction/the-kingdom-that-failed
# Finished processing: The Kingdom That Failed
# Processing story: The Kingdom That Failed
# Finished processing: The Kingdom That Failed
# Processing story: The Kingdom That Failed
# Finished processing: The Kingdom That Failed
# Processing story: The Kingdom That Failed
# Finished processing: The Kingdom That Failed
# Dataset completed and saved to 'completed_dataset.json'
